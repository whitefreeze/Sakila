# %% [markdown]
# # Sakila Queries

# %% [markdown]
# ## Import Packages

# %%
# Import Pandas
import pandas as pd

# PyMySQL
import pymysql
pymysql.install_as_MySQLdb()

# SQLAlchemy
from sqlalchemy import create_engine

from urllib.parse import quote_plus

# %% [markdown]
# ## Load Data

# %%
# Create connection string using credentials following this format
# connection = "dialect+driver://username:password@host:port/database"
username = "root"
# password = quote_plus("") 
db_name = "Sakila"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/Sakila)

# %%
q = """SELECT * FROM customer;"""
pd.read_sql(q, engine)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# 4       ELIZABETH.BROWN@sakilacustomer.org           9       1
# ..                                     ...         ...     ...
# 594  TERRENCE.GUNDERSON@sakilacustomer.org         601       1
# 595    ENRIQUE.FORSYTHE@sakilacustomer.org         602       1
# 596      FREDDIE.DUGGAN@sakilacustomer.org         603       1
# 597       WADE.DELVALLE@sakilacustomer.org         604       1
# 598      AUSTIN.CINTRON@sakilacustomer.org         605       1
#
#             create_date         last_update
# 0   2006-02-14 22:04:36 2006-02-14 12:57:20
# 1   2006-02-14 22:04:36 2006-02-14 12:57:20
# 2   2006-02-14 22:04:36 2006-02-14 12:57:20
# 3   2006-02-14 22:04:36 2006-02-14 12:57:20
# 4   2006-02-14 22:04:36 2006-02-14 12:57:20
# ..                  ...                 ...
# 594 2006-02-14 22:04:37 2006-02-14 12:57:20
# 595 2006-02-14 22:04:37 2006-02-14 12:57:20
# 596 2006-02-14 22:04:37 2006-02-14 12:57:20
# 597 2006-02-14 22:04:37 2006-02-14 12:57:20
# 598 2006-02-14 22:04:37 2006-02-14 12:57:20
#
# [599 rows x 9 columns]

# %% [markdown]
# Data has been connected and loaded correctly.

# %% [markdown]
# ## Sakila ERD

# %% [markdown]
# ![png](https://assets.codingdojo.com/boomyeah/company_209/chapter_3569/handouts/chapter3569_5431_sakila-db-model.png)

# %% [markdown]
# ## Queries

# %%
# 1. What query would you run to get all the customers inside city_id = 312? 
# Your query should return the customers' first name, last name, email, address, and city.

q = """
SELECT c.first_name, c.last_name, c.email, address.address, city.city, city.city_id 
FROM customer AS c 
JOIN address ON address.address_id = c.address_id
JOIN city ON city.city_id = address.city_id
WHERE city.city_id = 312;
"""
pd.read_sql(q, engine)
# Out:
#   first_name last_name                              email             address  \
# 0     MATTIE   HOFFMAN  MATTIE.HOFFMAN@sakilacustomer.org   1497 Yuzhou Drive
# 1      CECIL     VINES     CECIL.VINES@sakilacustomer.org  548 Uruapan Street
#
#      city  city_id
# 0  London      312
# 1  London      312

# %%
# 2. What query would you run to get all comedy films? 
# Note that the genre is called the category in this schema. 
# Your query should return film title, description, release year, rating, and special features.

q = """
SELECT f.title, f.description, f.release_year, f.rating, f.special_features, category.name 
FROM film AS f 
JOIN film_category ON f.film_id = film_category.film_id
JOIN category ON film_category.category_id = category.category_id
WHERE category.name = 'Comedy';
"""
pd.read_sql(q, engine)
# Out:
#                       title  \
# 0           AIRPLANE SIERRA
# 1               ANTHEM LUKE
# 2       BRINGING HYSTERICAL
# 3             CAPER MOTIONS
# 4             CAT CONEHEADS
# 5               CLOSER BANG
# 6    CONNECTION MICROCOSMOS
# 7            CONTROL ANTHEM
# 8                CRAZY HOME
# 9          DADDY PITTSBURGH
# 10             DOOM DANCING
# 11          DOWNHILL ENOUGH
# 12              DYING MAKER
# 13           ELEMENT FREDDY
# 14            FERRIS MOTHER
# 15    FIREBALL PHILADELPHIA
# 16    FLINTSTONES HAPPINESS
# 17    FRANKENSTEIN STRANGER
# 18        FREEDOM CLEOPATRA
# 19               GOLD RIVER
# 20          GROUNDHOG UNCUT
# 21            GUNFIGHT MOON
# 22            HATE HANDICAP
# 23           HEAVEN FREEDOM
# 24             HEDWIG ALTER
# 25         HURRICANE AFFAIR
# 26            HUSTLER PARTY
# 27               JAWS HARRY
# 28            KNOCK WARLOCK
# 29             LIFE TWISTED
# 30               LION UNCUT
# 31          LONELY ELEPHANT
# 32          MALLRATS UNITED
# 33        MEMENTO ZOOLANDER
# 34               MULAN MOON
# 35            MYSTIC TRUMAN
# 36      OPERATION OPERATION
# 37         PARADISE SABRINA
# 38              PARTY KNOCK
# 39           PERFECT GROOVE
# 40          PINOCCHIO SIMON
# 41              PURE RUNNER
# 42         RUSHMORE MERMAID
# 43         SADDLE ANTITRUST
# 44              SATURN NAME
# 45           SEARCHERS WAIT
# 46           SNATCH SLIPPER
# 47              STAGE WORLD
# 48        STRICTLY SCARFACE
# 49            SUBMARINE BED
# 50           SWEDEN SHINING
# 51  TRAINSPOTTING STRANGERS
# 52             TRAMP OTHERS
# 53            VALLEY PACKER
# 54        VELVET TERMINATOR
# 55        VERTIGO NORTHWEST
# 56            WISDOM WORKER
# 57                ZORRO ARK
#
#                                           description  release_year rating  \
# 0   A Touching Saga of a Hunter And a Butler who m...          2006  PG-13
# 1   A Touching Panorama of a Waitress And a Woman ...          2006  PG-13
# 2   A Fateful Saga of a A Shark And a Technical Wr...          2006     PG
# 3   A Fateful Saga of a Moose And a Car who must P...          2006      G
# 4   A Fast-Paced Panorama of a Girl And a A Shark ...          2006      G
# 5   A Unbelieveable Panorama of a Frisbee And a Hu...          2006      R
# 6   A Fateful Documentary of a Crocodile And a Hus...          2006      G
# 7   A Fateful Documentary of a Robot And a Student...          2006      G
# 8   A Fanciful Panorama of a Boy And a Woman who m...          2006     PG
# 9   A Epic Story of a A Shark And a Student who mu...          2006      G
# 10  A Astounding Panorama of a Car And a Mad Scien...          2006      R
# 11  A Emotional Tale of a Pastry Chef And a Forens...          2006      G
# 12  A Intrepid Tale of a Boat And a Monkey who mus...          2006     PG
# 13  A Awe-Inspiring Reflection of a Waitress And a...          2006  NC-17
# 14  A Touching Display of a Frisbee And a Frisbee ...          2006     PG
# 15  A Amazing Yarn of a Dentist And a A Shark who ...          2006     PG
# 16  A Fateful Story of a Husband And a Moose who m...          2006  PG-13
# 17  A Insightful Character Study of a Feminist And...          2006  NC-17
# 18  A Emotional Reflection of a Dentist And a Mad ...          2006  PG-13
# 19  A Taut Documentary of a Database Administrator...          2006      R
# 20  A Brilliant Panorama of a Astronaut And a Tech...          2006  PG-13
# 21  A Epic Reflection of a Pastry Chef And a Explo...          2006  NC-17
# 22  A Intrepid Reflection of a Mad Scientist And a...          2006     PG
# 23  A Intrepid Story of a Butler And a Car who mus...          2006     PG
# 24  A Action-Packed Yarn of a Womanizer And a Lumb...          2006  NC-17
# 25  A Lacklusture Epistle of a Database Administra...          2006     PG
# 26  A Emotional Reflection of a Sumo Wrestler And ...          2006  NC-17
# 27  A Thrilling Display of a Database Administrato...          2006      G
# 28  A Unbelieveable Story of a Teacher And a Boat ...          2006  PG-13
# 29  A Thrilling Reflection of a Teacher And a Comp...          2006  NC-17
# 30  A Intrepid Display of a Pastry Chef And a Cat ...          2006     PG
# 31  A Intrepid Story of a Student And a Dog who mu...          2006      G
# 32  A Thrilling Yarn of a Waitress And a Dentist w...          2006     PG
# 33  A Touching Epistle of a Squirrel And a Explore...          2006  NC-17
# 34  A Emotional Saga of a Womanizer And a Pioneer ...          2006      G
# 35  A Epic Yarn of a Teacher And a Hunter who must...          2006  NC-17
# 36  A Intrepid Character Study of a Man And a Fris...          2006      G
# 37  A Intrepid Yarn of a Car And a Moose who must ...          2006  PG-13
# 38  A Fateful Display of a Technical Writer And a ...          2006     PG
# 39  A Thrilling Yarn of a Dog And a Dog who must B...          2006  PG-13
# 40  A Action-Packed Reflection of a Mad Scientist ...          2006     PG
# 41  A Thoughtful Documentary of a Student And a Ma...          2006  NC-17
# 42  A Boring Story of a Woman And a Moose who must...          2006  PG-13
# 43  A Stunning Epistle of a Feminist And a A Shark...          2006  PG-13
# 44  A Fateful Epistle of a Butler And a Boy who mu...          2006      R
# 45  A Fast-Paced Tale of a Car And a Mad Scientist...          2006  NC-17
# 46  A Insightful Panorama of a Woman And a Feminis...          2006     PG
# 47  A Lacklusture Panorama of a Woman And a Frisbe...          2006     PG
# 48  A Touching Reflection of a Crocodile And a Dog...          2006  PG-13
# 49  A Amazing Display of a Car And a Monkey who mu...          2006      R
# 50  A Taut Documentary of a Car And a Robot who mu...          2006     PG
# 51  A Fast-Paced Drama of a Pioneer And a Mad Cow ...          2006  PG-13
# 52  A Brilliant Display of a Composer And a Cat wh...          2006     PG
# 53  A Astounding Documentary of a Astronaut And a ...          2006      G
# 54  A Lacklusture Tale of a Pastry Chef And a Tech...          2006      R
# 55  A Unbelieveable Display of a Mad Scientist And...          2006      R
# 56  A Unbelieveable Saga of a Forensic Psychologis...          2006      R
# 57  A Intrepid Panorama of a Mad Scientist And a B...          2006  NC-17
#
#                                      special_features    name
# 0                             Trailers,Deleted Scenes  Comedy
# 1                    Deleted Scenes,Behind the Scenes  Comedy
# 2                                            Trailers  Comedy
# 3                Trailers,Commentaries,Deleted Scenes  Comedy
# 4                         Commentaries,Deleted Scenes  Comedy
# 5                          Trailers,Behind the Scenes  Comedy
# 6                    Deleted Scenes,Behind the Scenes  Comedy
# 7                                        Commentaries  Comedy
# 8                         Commentaries,Deleted Scenes  Comedy
# 9                    Deleted Scenes,Behind the Scenes  Comedy
# 10                              Trailers,Commentaries  Comedy
# 11               Trailers,Commentaries,Deleted Scenes  Comedy
# 12                                  Behind the Scenes  Comedy
# 13                     Commentaries,Behind the Scenes  Comedy
# 14          Trailers,Deleted Scenes,Behind the Scenes  Comedy
# 15            Trailers,Commentaries,Behind the Scenes  Comedy
# 16  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 17                   Deleted Scenes,Behind the Scenes  Comedy
# 18            Trailers,Commentaries,Behind the Scenes  Comedy
# 19  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 20  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 21                   Deleted Scenes,Behind the Scenes  Comedy
# 22            Trailers,Commentaries,Behind the Scenes  Comedy
# 23                                       Commentaries  Comedy
# 24            Trailers,Commentaries,Behind the Scenes  Comedy
# 25            Trailers,Commentaries,Behind the Scenes  Comedy
# 26            Trailers,Commentaries,Behind the Scenes  Comedy
# 27                                     Deleted Scenes  Comedy
# 28                                           Trailers  Comedy
# 29                        Commentaries,Deleted Scenes  Comedy
# 30                            Trailers,Deleted Scenes  Comedy
# 31  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 32               Trailers,Commentaries,Deleted Scenes  Comedy
# 33                                  Behind the Scenes  Comedy
# 34                                  Behind the Scenes  Comedy
# 35                     Commentaries,Behind the Scenes  Comedy
# 36  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 37      Commentaries,Deleted Scenes,Behind the Scenes  Comedy
# 38                         Trailers,Behind the Scenes  Comedy
# 39      Commentaries,Deleted Scenes,Behind the Scenes  Comedy
# 40                     Commentaries,Behind the Scenes  Comedy
# 41                            Trailers,Deleted Scenes  Comedy
# 42               Trailers,Commentaries,Deleted Scenes  Comedy
# 43                            Trailers,Deleted Scenes  Comedy
# 44  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 45  Trailers,Commentaries,Deleted Scenes,Behind th...  Comedy
# 46                                       Commentaries  Comedy
# 47                     Commentaries,Behind the Scenes  Comedy
# 48      Commentaries,Deleted Scenes,Behind the Scenes  Comedy
# 49                                           Trailers  Comedy
# 50                   Deleted Scenes,Behind the Scenes  Comedy
# 51                                           Trailers  Comedy
# 52                                     Deleted Scenes  Comedy
# 53                        Commentaries,Deleted Scenes  Comedy
# 54                                  Behind the Scenes  Comedy
# 55                     Commentaries,Behind the Scenes  Comedy
# 56                   Deleted Scenes,Behind the Scenes  Comedy
# 57            Trailers,Commentaries,Behind the Scenes  Comedy

# %%
# 3. What query would you run to get all the films that Johnny Lollobrigida was in? 
# Your query should return the actor's last name, film title, and release year.

q = """
SELECT actor.first_name, actor.last_name, f.title, f.release_year 
FROM film AS f
JOIN film_actor ON film_actor.film_id = f.film_id
JOIN actor ON actor.actor_id = film_actor.actor_id
WHERE actor.last_name = 'Lollobrigida';
"""
pd.read_sql(q, engine)
# Out:
#    first_name     last_name                 title  release_year
# 0      JOHNNY  LOLLOBRIGIDA          AMADEUS HOLY          2006
# 1      JOHNNY  LOLLOBRIGIDA      BANGER PINOCCHIO          2006
# 2      JOHNNY  LOLLOBRIGIDA      BONNIE HOLOCAUST          2006
# 3      JOHNNY  LOLLOBRIGIDA           CHITTY LOCK          2006
# 4      JOHNNY  LOLLOBRIGIDA  COMMANDMENTS EXPRESS          2006
# 5      JOHNNY  LOLLOBRIGIDA     CONEHEADS SMOOCHY          2006
# 6      JOHNNY  LOLLOBRIGIDA      DADDY PITTSBURGH          2006
# 7      JOHNNY  LOLLOBRIGIDA       DAISY MENAGERIE          2006
# 8      JOHNNY  LOLLOBRIGIDA         ENOUGH RAGING          2006
# 9      JOHNNY  LOLLOBRIGIDA     ESCAPE METROPOLIS          2006
# 10     JOHNNY  LOLLOBRIGIDA           FIRE WOLVES          2006
# 11     JOHNNY  LOLLOBRIGIDA        FRONTIER CABIN          2006
# 12     JOHNNY  LOLLOBRIGIDA     GOODFELLAS SALUTE          2006
# 13     JOHNNY  LOLLOBRIGIDA    GRAIL FRANKENSTEIN          2006
# 14     JOHNNY  LOLLOBRIGIDA        GROOVE FICTION          2006
# 15     JOHNNY  LOLLOBRIGIDA          HALL CASSIDY          2006
# 16     JOHNNY  LOLLOBRIGIDA          HEAVENLY GUN          2006
# 17     JOHNNY  LOLLOBRIGIDA      KRAMER CHOCOLATE          2006
# 18     JOHNNY  LOLLOBRIGIDA         LOVE SUICIDES          2006
# 19     JOHNNY  LOLLOBRIGIDA      METAL ARMAGEDDON          2006
# 20     JOHNNY  LOLLOBRIGIDA       PACIFIC AMISTAD          2006
# 21     JOHNNY  LOLLOBRIGIDA      PATTON INTERVIEW          2006
# 22     JOHNNY  LOLLOBRIGIDA            POCUS PULP          2006
# 23     JOHNNY  LOLLOBRIGIDA   RIDGEMONT SUBMARINE          2006
# 24     JOHNNY  LOLLOBRIGIDA   RINGS HEARTBREAKERS          2006
# 25     JOHNNY  LOLLOBRIGIDA         SMILE EARRING          2006
# 26     JOHNNY  LOLLOBRIGIDA    SOLDIERS EVOLUTION          2006
# 27     JOHNNY  LOLLOBRIGIDA        STAR OPERATION          2006
# 28     JOHNNY  LOLLOBRIGIDA        SUNRISE LEAGUE          2006

# %%
# 4. What query would you run to get the 
# first and last names of all the actors in the movie titled "Bingo Talented"?

q = """
SELECT a.first_name, a.last_name, film.title
FROM actor AS a
JOIN film_actor ON film_actor.actor_id = a.actor_id
JOIN film ON film.film_id = film_actor.film_id
WHERE film.title = 'Bingo Talented';
"""
pd.read_sql(q, engine)
# Out:
#   first_name    last_name           title
# 0     GOLDIE        BRODY  BINGO TALENTED
# 1    CAMERON         WRAY  BINGO TALENTED
# 2       CARY  MCCONAUGHEY  BINGO TALENTED
# 3        JON        CHASE  BINGO TALENTED
# 4      RENEE         BALL  BINGO TALENTED

# %%
# 5. What query would you run to get the customer_id associated with 
# all payments greater than twice the average payment amount? 
# (HINT: use 2* in your query to get twice the amount). 
# Your result should include the customer id and the amount.

q = """
SELECT customer.customer_id, payment.amount, (SELECT AVG(payment.amount) * 2 FROM payment) AS 2x_avg_payment
FROM customer
JOIN payment ON customer.customer_id = payment.customer_id
WHERE payment.amount > (SELECT AVG(payment.amount) * 2 FROM payment);
"""
pd.read_sql(q, engine)
# Out:
#      customer_id  amount  2x_avg_payment
# 0              1    9.99        8.401335
# 1              2   10.99        8.401335
# 2              3    8.99        8.401335
# 3              3   10.99        8.401335
# 4              3    8.99        8.401335
# ..           ...     ...             ...
# 852          595    9.99        8.401335
# 853          595   10.99        8.401335
# 854          597    8.99        8.401335
# 855          599    9.99        8.401335
# 856          599    8.99        8.401335
#
# [857 rows x 3 columns]

# %%
# 6. What query would you run to list the first and last names of the 5 customers 
# who have the highest number(count) of payments? 
# You can title the number of payments as num_payments.

q = """
SELECT DISTINCT customer.first_name, customer.last_name, COUNT(payment.payment_id) AS num_payments
FROM customer
JOIN payment ON customer.customer_id = payment.customer_id
GROUP BY customer.customer_id
ORDER BY COUNT(payment.payment_id) DESC;
"""
pd.read_sql(q, engine)
# Out:
#     first_name last_name  num_payments
# 0      ELEANOR      HUNT            46
# 1         KARL      SEAL            45
# 2        CLARA      SHAW            42
# 3       MARCIA      DEAN            42
# 4        TAMMY   SANDERS            41
# ..         ...       ...           ...
# 594   CAROLINE    BOWMAN            15
# 595  KATHERINE    RIVERA            14
# 596      LEONA    OBRIEN            14
# 597    TIFFANY    JORDAN            14
# 598      BRIAN     WYMAN            12
#
# [599 rows x 3 columns]
